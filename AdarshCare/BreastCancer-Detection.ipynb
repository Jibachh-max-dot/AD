# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# We would drop "Unnamed: 32", "id" from the dataset, as they are not beneficial for our analysis
df.drop(['Unnamed: 32', 'id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['diagnosis'].nunique()
# Out:
# 2

# %% [markdown]
# ### Hence, we have "diagnosis" as the target variable, which has two values, M(Malign) and B(Benign)
# ### After doing PCA(Principal Component Analysis), we find out that features like 'concave points_mean','area_mean','radius_mean','perimeter_mean','concavity_mean' are important for our prediction

# %%
df = df[['concave points_mean','area_mean','radius_mean','perimeter_mean','concavity_mean', 'diagnosis']]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head(20)
# Out:
#     concave points_mean  area_mean  radius_mean  perimeter_mean  \
# 0               0.14710     1001.0        17.99          122.80
# 1               0.07017     1326.0        20.57          132.90
# 2               0.12790     1203.0        19.69          130.00
# 3               0.10520      386.1        11.42           77.58
# 4               0.10430     1297.0        20.29          135.10
# 5               0.08089      477.1        12.45           82.57
# 6               0.07400     1040.0        18.25          119.60
# 7               0.05985      577.9        13.71           90.20
# 8               0.09353      519.8        13.00           87.50
# 9               0.08543      475.9        12.46           83.97
# 10              0.03323      797.8        16.02          102.70
# 11              0.06606      781.0        15.78          103.60
# 12              0.11180     1123.0        19.17          132.40
# 13              0.05364      782.7        15.85          103.70
# ...

# %%
encoder = LabelEncoder()
diagnosisEncoded = encoder.fit_transform(df['diagnosis'])
df['diagnosis'] = diagnosisEncoded

# %%
df.head(20)
# Out:
#     concave points_mean  area_mean  radius_mean  perimeter_mean  \
# 0               0.14710     1001.0        17.99          122.80
# 1               0.07017     1326.0        20.57          132.90
# 2               0.12790     1203.0        19.69          130.00
# 3               0.10520      386.1        11.42           77.58
# 4               0.10430     1297.0        20.29          135.10
# 5               0.08089      477.1        12.45           82.57
# 6               0.07400     1040.0        18.25          119.60
# 7               0.05985      577.9        13.71           90.20
# 8               0.09353      519.8        13.00           87.50
# 9               0.08543      475.9        12.46           83.97
# 10              0.03323      797.8        16.02          102.70
# 11              0.06606      781.0        15.78          103.60
# 12              0.11180     1123.0        19.17          132.40
# 13              0.05364      782.7        15.85          103.70
# ...

# %%
X = df.drop(['diagnosis'], axis=1)
y = df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
model = RandomForestClassifier()
model.fit(X_train, y_train)
predictionsRF = model.predict(X_test)

# %%
def calculateMetrics(model):
    print(classification_report(y_test, model))
    print('\n')
    print(confusion_matrix(y_test, model))

# %%
calculateMetrics(predictionsRF)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       105
#            1       0.91      0.89      0.90        66
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.92      0.92       171
# weighted avg       0.92      0.92      0.92       171
#
#
#
# [[99  6]
#  [ 7 59]]

# %%
logModel = LogisticRegression()

# %%
X.head()
# Out:
#    concave points_mean  area_mean  radius_mean  perimeter_mean  concavity_mean
# 0              0.14710     1001.0        17.99          122.80          0.3001
# 1              0.07017     1326.0        20.57          132.90          0.0869
# 2              0.12790     1203.0        19.69          130.00          0.1974
# 3              0.10520      386.1        11.42           77.58          0.2414
# 4              0.10430     1297.0        20.29          135.10          0.1980

# %%
logModel.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictionsLog = logModel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
def calculateMetrics(model):
    print(classification_report(y_test, model))
    print('\n')
    print(confusion_matrix(y_test, model))

# %%
calculateMetrics(predictionsLog)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       105
#            1       0.87      0.83      0.85        66
#
#     accuracy                           0.89       171
#    macro avg       0.89      0.88      0.88       171
# weighted avg       0.89      0.89      0.89       171
#
#
#
# [[97  8]
#  [11 55]]

# %%
import pickle
pickle_out = open("RFModelCacner.pkl", "wb")
pickle.dump(model, pickle_out)
pickle_out.close()
